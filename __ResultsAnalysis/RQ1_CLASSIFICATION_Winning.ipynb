# %%
# Loading packages
import os
import csv
import numpy as np
from numpy import quantile, random, where
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import category_encoders as ce
import collections
from sklearn import preprocessing
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import IsolationForest
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from scipy.stats import kurtosis
from scipy.stats import skew
import missingno as msno
from sklearn import svm
from imblearn.over_sampling import SMOTE

# %%
# Load the DataFrame from the pickle file
df = pd.read_pickle('documents_topics.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57790 entries, 0 to 57789
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      57790 non-null  object
#  1   text                          57790 non-null  object
#  2   created_at                    57790 non-null  object
#  3   campaign_week                 57790 non-null  int64
#  4   process_text_check            57790 non-null  object
#  5   name                          57790 non-null  object
#  6   handle                        57790 non-null  object
#  7   party                         57790 non-null  object
#  8   state_code                    57790 non-null  object
#  9   state_name                    57790 non-null  object
#  10  result_pctg                   57790 non-null  float64
#  11  result_votes                  57790 non-null  int64
#  12  position                      57790 non-null  int64
#  13  total_votes_casted            57790 non-null  int64
#  14  winner_margin_for_runners_up  57790 non-null  float64
#  15  check_city_filtered           20226 non-null  object
#  16  PreProcessedText_WithoutCity  57790 non-null  object
#  17  Words                         57790 non-null  object
#  18  WordsCleaned                  57790 non-null  object
#  19  WordsLemmatized               57790 non-null  object
#  20  Campaign Event                57790 non-null  float64
#  21  Social Protection             57790 non-null  float64
#  22  General Discussion            57790 non-null  float64
#  23  Abortion                      57790 non-null  float64
#  24  Homeland Security             57790 non-null  float64
#  25  Candidate Denigration         57790 non-null  float64
#  26  Vote Instigation              57790 non-null  float64
#  27  Campaign Contribution         57790 non-null  float64
#  28  Economy Policies              57790 non-null  float64
# dtypes: float64(11), int64(4), object(14)
# memory usage: 12.8+ MB

# %% [markdown]
# ## Test for RQ1

# %%
#transform topics to know if there were city reference in the tweet or not

columns_to_replicate = [
    'Campaign Event', 'Social Protection', 'General Discussion', 'Abortion',
    'Homeland Security', 'Candidate Denigration', 'Vote Instigation',
    'Campaign Contribution', 'Economy Policies'
]

def create_new_columns(row):
    new_data = {}
    check_city_filtered_na = pd.isna(row['check_city_filtered'])

    # If 'check_city_filtered' contains an array, use any() function, else use the value directly
    if isinstance(check_city_filtered_na, np.ndarray):
        has_missing_values = check_city_filtered_na.any()
    else:
        has_missing_values = check_city_filtered_na

    for col in columns_to_replicate:
        if has_missing_values:
            new_data[col + '_withoutlocaltweet'] = row[col]
        else:
            new_data[col + '_withlocaltweet'] = row[col]
    return pd.Series(new_data)

# Apply the function to the DataFrame and concatenate the resulting columns
new_columns = df.apply(create_new_columns, axis=1)

# Fill NaN values with 0 in the new_columns DataFrame
new_columns = new_columns.fillna(0)

df_base = pd.concat([df, new_columns], axis=1)
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57790 entries, 0 to 57789
# Data columns (total 47 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   tweet_id                                 57790 non-null  object
#  1   text                                     57790 non-null  object
#  2   created_at                               57790 non-null  object
#  3   campaign_week                            57790 non-null  int64
#  4   process_text_check                       57790 non-null  object
#  5   name                                     57790 non-null  object
#  6   handle                                   57790 non-null  object
#  7   party                                    57790 non-null  object
#  8   state_code                               57790 non-null  object
#  9   state_name                               57790 non-null  object
#  10  result_pctg                              57790 non-null  float64
#  11  result_votes                             57790 non-null  int64
#  12  position                                 57790 non-null  int64
#  13  total_votes_casted                       57790 non-null  int64
#  14  winner_margin_for_runners_up             57790 non-null  float64
#  15  check_city_filtered                      20226 non-null  object
#  16  PreProcessedText_WithoutCity             57790 non-null  object
#  17  Words                                    57790 non-null  object
#  18  WordsCleaned                             57790 non-null  object
#  19  WordsLemmatized                          57790 non-null  object
#  20  Campaign Event                           57790 non-null  float64
#  21  Social Protection                        57790 non-null  float64
#  22  General Discussion                       57790 non-null  float64
#  23  Abortion                                 57790 non-null  float64
#  24  Homeland Security                        57790 non-null  float64
#  25  Candidate Denigration                    57790 non-null  float64
#  26  Vote Instigation                         57790 non-null  float64
#  27  Campaign Contribution                    57790 non-null  float64
#  28  Economy Policies                         57790 non-null  float64
#  29  Abortion_withlocaltweet                  57790 non-null  float64
#  30  Abortion_withoutlocaltweet               57790 non-null  float64
#  31  Campaign Contribution_withlocaltweet     57790 non-null  float64
#  32  Campaign Contribution_withoutlocaltweet  57790 non-null  float64
#  33  Campaign Event_withlocaltweet            57790 non-null  float64
#  34  Campaign Event_withoutlocaltweet         57790 non-null  float64
#  35  Candidate Denigration_withlocaltweet     57790 non-null  float64
#  36  Candidate Denigration_withoutlocaltweet  57790 non-null  float64
#  37  Economy Policies_withlocaltweet          57790 non-null  float64
#  38  Economy Policies_withoutlocaltweet       57790 non-null  float64
#  39  General Discussion_withlocaltweet        57790 non-null  float64
#  40  General Discussion_withoutlocaltweet     57790 non-null  float64
#  41  Homeland Security_withlocaltweet         57790 non-null  float64
#  42  Homeland Security_withoutlocaltweet      57790 non-null  float64
#  43  Social Protection_withlocaltweet         57790 non-null  float64
#  44  Social Protection_withoutlocaltweet      57790 non-null  float64
#  45  Vote Instigation_withlocaltweet          57790 non-null  float64
#  46  Vote Instigation_withoutlocaltweet       57790 non-null  float64
# dtypes: float64(29), int64(4), object(14)
# memory usage: 20.7+ MB

# %%
# Columns you want to include in the new dataset
selected_columns = ['name','party','position','Abortion_withlocaltweet','Abortion_withoutlocaltweet','Campaign Contribution_withlocaltweet','Campaign Contribution_withoutlocaltweet',
                    'Campaign Event_withlocaltweet','Campaign Event_withoutlocaltweet','Candidate Denigration_withlocaltweet','Candidate Denigration_withoutlocaltweet','Economy Policies_withlocaltweet','Economy Policies_withoutlocaltweet',
                    'General Discussion_withlocaltweet','General Discussion_withoutlocaltweet','Homeland Security_withlocaltweet',
                    'Homeland Security_withoutlocaltweet','Social Protection_withlocaltweet','Social Protection_withoutlocaltweet',
                    'Vote Instigation_withlocaltweet','Vote Instigation_withoutlocaltweet']

# Create a new DataFrame with the selected columns
df_wip = df_base[selected_columns]
df_wip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57790 entries, 0 to 57789
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   name                                     57790 non-null  object
#  1   party                                    57790 non-null  object
#  2   position                                 57790 non-null  int64
#  3   Abortion_withlocaltweet                  57790 non-null  float64
#  4   Abortion_withoutlocaltweet               57790 non-null  float64
#  5   Campaign Contribution_withlocaltweet     57790 non-null  float64
#  6   Campaign Contribution_withoutlocaltweet  57790 non-null  float64
#  7   Campaign Event_withlocaltweet            57790 non-null  float64
#  8   Campaign Event_withoutlocaltweet         57790 non-null  float64
#  9   Candidate Denigration_withlocaltweet     57790 non-null  float64
#  10  Candidate Denigration_withoutlocaltweet  57790 non-null  float64
#  11  Economy Policies_withlocaltweet          57790 non-null  float64
#  12  Economy Policies_withoutlocaltweet       57790 non-null  float64
#  13  General Discussion_withlocaltweet        57790 non-null  float64
#  14  General Discussion_withoutlocaltweet     57790 non-null  float64
#  15  Homeland Security_withlocaltweet         57790 non-null  float64
#  16  Homeland Security_withoutlocaltweet      57790 non-null  float64
#  17  Social Protection_withlocaltweet         57790 non-null  float64
#  18  Social Protection_withoutlocaltweet      57790 non-null  float64
#  19  Vote Instigation_withlocaltweet          57790 non-null  float64
#  20  Vote Instigation_withoutlocaltweet       57790 non-null  float64
# dtypes: float64(18), int64(1), object(2)
# memory usage: 9.3+ MB

# %% [markdown]
# ## Let's try predicting winning or not

# %%
#create a dataframe with the values for the algorithms

agg_dict = {
    #aggregate the numerical values
    'Abortion_withlocaltweet': 'mean',
    'Abortion_withoutlocaltweet': 'mean',
    'Campaign Contribution_withlocaltweet': 'mean',
    'Campaign Contribution_withoutlocaltweet': 'mean',
    'Campaign Event_withlocaltweet': 'mean',
    'Campaign Event_withoutlocaltweet': 'mean',
    'Candidate Denigration_withlocaltweet': 'mean',
    'Candidate Denigration_withoutlocaltweet': 'mean',
    'Economy Policies_withlocaltweet': 'mean',
    'Economy Policies_withoutlocaltweet': 'mean',
    'General Discussion_withlocaltweet': 'mean',
    'General Discussion_withoutlocaltweet': 'mean',
    'Homeland Security_withlocaltweet': 'mean',
    'Homeland Security_withoutlocaltweet': 'mean',
    'Social Protection_withlocaltweet': 'mean',
    'Social Protection_withoutlocaltweet': 'mean',
    'Vote Instigation_withlocaltweet': 'mean',
    'Vote Instigation_withoutlocaltweet': 'mean',
    #now the categorical values
    'party':'last',
    'position':'last'
}


#create the new dataframe
df_wip = df_wip.groupby(['name']).agg(agg_dict).reset_index()

# %%
df_wip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   name                                     79 non-null     object
#  1   Abortion_withlocaltweet                  79 non-null     float64
#  2   Abortion_withoutlocaltweet               79 non-null     float64
#  3   Campaign Contribution_withlocaltweet     79 non-null     float64
#  4   Campaign Contribution_withoutlocaltweet  79 non-null     float64
#  5   Campaign Event_withlocaltweet            79 non-null     float64
#  6   Campaign Event_withoutlocaltweet         79 non-null     float64
#  7   Candidate Denigration_withlocaltweet     79 non-null     float64
#  8   Candidate Denigration_withoutlocaltweet  79 non-null     float64
#  9   Economy Policies_withlocaltweet          79 non-null     float64
#  10  Economy Policies_withoutlocaltweet       79 non-null     float64
#  11  General Discussion_withlocaltweet        79 non-null     float64
#  12  General Discussion_withoutlocaltweet     79 non-null     float64
#  13  Homeland Security_withlocaltweet         79 non-null     float64
#  14  Homeland Security_withoutlocaltweet      79 non-null     float64
#  15  Social Protection_withlocaltweet         79 non-null     float64
#  16  Social Protection_withoutlocaltweet      79 non-null     float64
#  17  Vote Instigation_withlocaltweet          79 non-null     float64
#  18  Vote Instigation_withoutlocaltweet       79 non-null     float64
#  19  party                                    79 non-null     object
#  20  position                                 79 non-null     int64
# dtypes: float64(18), int64(1), object(2)
# memory usage: 13.1+ KB

# %%
#transform position into winning or not
df_wip['is_winner'] = (df_wip['position'] == 1).astype(int)

#remove name and position columns
df_wip = df_wip.drop(columns=['name','position'], axis=1)
# Encode categorical values into dummy variables
cols = ['party']
ce_one_hot = ce.OneHotEncoder(cols = cols, use_cat_names=True)
ds_work = ce_one_hot.fit_transform(df_wip)

# %%
#normalization of the data to make model with better accuracy
ds_work = pd.DataFrame(preprocessing.MinMaxScaler().fit_transform(ds_work.values), columns=ds_work.columns,index=ds_work.index)
ds_work.describe()
# Out:
#        Abortion_withlocaltweet  Abortion_withoutlocaltweet  \
# count                79.000000                   79.000000
# mean                  0.223379                    0.328696
# std                   0.163644                    0.190692
# min                   0.000000                    0.000000
# 25%                   0.118809                    0.201083
# 50%                   0.197744                    0.294744
# 75%                   0.264006                    0.425707
# max                   1.000000                    1.000000
#
#        Campaign Contribution_withlocaltweet  \
# count                             79.000000
# mean                               0.121294
# std                                0.132847
# min                                0.000000
# 25%                                0.052310
# 50%                                0.089315
# 75%                                0.137900
# max                                1.000000
#
#        Campaign Contribution_withoutlocaltweet  Campaign Event_withlocaltweet  \
# count                                79.000000                      79.000000
# mean                                  0.203639                       0.329205
# std                                   0.184078                       0.210772
# min                                   0.000000                       0.000000
# 25%                                   0.103991                       0.197570
# 50%                                   0.156488                       0.319963
# 75%                                   0.235425                       0.421236
# max                                   1.000000                       1.000000
#
#        Campaign Event_withoutlocaltweet  Candidate Denigration_withlocaltweet  \
# count                         79.000000                             79.000000
# mean                           0.357522                              0.154923
# std                            0.208714                              0.144303
# min                            0.000000                              0.000000
# 25%                            0.220371                              0.072023
# 50%                            0.314356                              0.116828
# 75%                            0.479142                              0.199893
# max                            1.000000                              1.000000
#
#        Candidate Denigration_withoutlocaltweet  \
# count                                79.000000
# mean                                  0.349174
# std                                   0.234181
# min                                   0.000000
# 25%                                   0.177146
# 50%                                   0.303888
# 75%                                   0.456053
# max                                   1.000000
#
#        Economy Policies_withlocaltweet  Economy Policies_withoutlocaltweet  \
# count                        79.000000                           79.000000
# mean                          0.180557                            0.280083
# std                           0.210120                            0.249743
# min                           0.000000                            0.000000
# 25%                           0.046691                            0.087300
# 50%                           0.087769                            0.181455
# 75%                           0.235860                            0.405702
# max                           1.000000                            1.000000
#
#        ...  Homeland Security_withoutlocaltweet  \
# count  ...                            79.000000
# mean   ...                             0.232496
# std    ...                             0.174119
# min    ...                             0.000000
# 25%    ...                             0.113403
# 50%    ...                             0.180746
# 75%    ...                             0.315999
# max    ...                             1.000000
#
#        Social Protection_withlocaltweet  Social Protection_withoutlocaltweet  \
# count                         79.000000                            79.000000
# mean                           0.312323                             0.318010
# std                            0.225976                             0.234405
# min                            0.000000                             0.000000
# 25%                            0.170531                             0.138322
# 50%                            0.233330                             0.288427
# 75%                            0.458644                             0.430415
# max                            1.000000                             1.000000
#
#        Vote Instigation_withlocaltweet  Vote Instigation_withoutlocaltweet  \
# count                        79.000000                           79.000000
# mean                          0.334670                            0.243688
# std                           0.218617                            0.177900
# min                           0.000000                            0.000000
# 25%                           0.202882                            0.127711
# 50%                           0.288000                            0.219074
# 75%                           0.410080                            0.323979
# max                           1.000000                            1.000000
#
#        party_Rep  party_Dem  party_Lib  party_Indpt  is_winner
# count  79.000000  79.000000  79.000000    79.000000  79.000000
# mean    0.443038   0.417722   0.113924     0.025316   0.430380
# std     0.499919   0.496335   0.319749     0.158088   0.498293
# min     0.000000   0.000000   0.000000     0.000000   0.000000
# 25%     0.000000   0.000000   0.000000     0.000000   0.000000
# 50%     0.000000   0.000000   0.000000     0.000000   0.000000
# 75%     1.000000   1.000000   0.000000     0.000000   1.000000
# max     1.000000   1.000000   1.000000     1.000000   1.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## *Modelling*
# ### Logistic Regression

# %%
# Create the Target
y = ds_work['is_winner']

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(ds_work, y, test_size=0.25, stratify=y, random_state=123)

# %%
# Remove the Target from the training
X_train = X_train.drop(['is_winner'],axis=1)
X_test = X_test.drop(['is_winner'],axis=1)

# %%
# Hyper Tuning Logistic Regression
grid_param = [{'solver':['liblinear', 'newton-cg','lbfgs'],  # <-- For reduction of time, we put liblinear because it is better for smaller datasets
               'verbose':[0,1],
               'multi_class':['auto','ovr','multinomial'],
               'max_iter':[100,300,500,700,900,1000,2000],
               'random_state':[123]}]
reg = LogisticRegression()
grid = GridSearchCV(reg, grid_param, cv=20)
grid.fit(X_train, y_train)
print("Grid search best parameters: {}".format(grid.best_params_))
# Out:
# [LibLinear]iter  1 act 1.033e+01 pre 9.741e+00 delta 2.762e+00 f 3.882e+01 |g| 9.689e+00 CG   4
# iter  2 act 2.352e-01 pre 2.251e-01 delta 2.762e+00 f 2.849e+01 |g| 1.646e+00 CG   4
# iter  3 act 1.756e-03 pre 1.751e-03 delta 2.762e+00 f 2.825e+01 |g| 1.322e-01 CG   4
# iter  4 act 5.500e-06 pre 5.501e-06 delta 2.762e+00 f 2.825e+01 |g| 4.622e-03 CG   4
# [LibLinear]iter  1 act 9.281e+00 pre 8.791e+00 delta 2.672e+00 f 3.882e+01 |g| 9.452e+00 CG   4
# iter  2 act 1.645e-01 pre 1.588e-01 delta 2.672e+00 f 2.954e+01 |g| 1.451e+00 CG   3
# iter  3 act 4.593e-03 pre 4.587e-03 delta 2.672e+00 f 2.937e+01 |g| 1.476e-01 CG   4
# iter  4 act 1.990e-05 pre 1.990e-05 delta 2.672e+00 f 2.937e+01 |g| 7.994e-03 CG   4
# iter  5 act 2.338e-08 pre 2.338e-08 delta 2.672e+00 f 2.937e+01 |g| 5.288e-04 CG   3
# [LibLinear]iter  1 act 1.082e+01 pre 1.020e+01 delta 2.802e+00 f 3.882e+01 |g| 1.009e+01 CG   4
# iter  2 act 2.515e-01 pre 2.406e-01 delta 2.802e+00 f 2.800e+01 |g| 1.706e+00 CG   4
M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  4.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    23     16     18      1     0     0   1.071D-04   2.892D+01
#   F =   28.917631725293553
#
# ...
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     22     25      1     0     0   7.427D-05   2.453D+01
#   F =   24.529839423435767
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  4.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     24     26      1     0     0   1.081D-04   2.560D+01
#   F =   25.603397528627397
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  4.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     23     26      1     0     0   9.352D-05   2.533D+01
#   F =   25.326393613764004
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  4.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     23     26      1     0     0   7.976D-05   2.611D+01
#   F =   26.111497416568390
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  4.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     21     25      1     0     0   6.905D-05   2.623D+01
#   F =   26.232987660413027
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  4.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     22     26      1     0     0   3.063D-05   2.594D+01
#   F =   25.944051090157583
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  4.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     25     28      1     0     0   1.545D-04   2.563D+01
#   F =   25.631157837054101
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  5.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     21     25      1     0     0   2.736D-04   2.511D+01
#   F =   25.106885050934437
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  5.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     21     25      1     0     0   6.613D-05   2.488D+01
#   F =   24.879698235876660
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  5.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     20     23      1     0     0   5.386D-05   2.457D+01
#   F =   24.567574523085248
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  5.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     23     27      1     0     0   1.937D-04   2.597D+01
#   F =   25.974055953969867
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.88162D+01    |proj g|=  5.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     21     23      1     0     0   7.610D-05   2.516D+01
#   F =   25.160613566059254
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           46     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.95094D+01    |proj g|=  4.50000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    46     24     28      1     0     0   5.447D-05   2.592D+01
#   F =   25.916192971055416
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Grid search best parameters: {'max_iter': 100, 'multi_class': 'multinomial', 'random_state': 123, 'solver': 'newton-cg', 'verbose': 0}
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#  This problem is unconstrained.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 280 fits failed out of a total of 2520.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 280 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1149, in fit
#     multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 97, in _check_multi_class
#     raise ValueError("Solver %s does not support a multinomial backend." % solver)
# ValueError: Solver liblinear does not support a multinomial backend.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.73333333 0.73333333 0.75       0.75       0.75       0.75
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#         nan        nan 0.76666667 0.76666667 0.76666667 0.76666667
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#         nan        nan 0.76666667 0.76666667 0.76666667 0.76666667
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#         nan        nan 0.76666667 0.76666667 0.76666667 0.76666667
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#         nan        nan 0.76666667 0.76666667 0.76666667 0.76666667
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#         nan        nan 0.76666667 0.76666667 0.76666667 0.76666667
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#         nan        nan 0.76666667 0.76666667 0.76666667 0.76666667
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#  0.73333333 0.73333333 0.75       0.75       0.75       0.75
#         nan        nan 0.76666667 0.76666667 0.76666667 0.76666667]
#   warnings.warn(

# %%
# Create object and train the model
classModel = LogisticRegression(**grid.best_params_)
classModel.fit(X_train, y_train)
# Out:
# LogisticRegression(multi_class='multinomial', random_state=123,
#                    solver='newton-cg')

# %%
#to create dataframe with metrics and insert the values in a already existing dataframe in order to compare all the models results
resultsDF_compare = pd.DataFrame()
resultsDF_compare['Measure'] = ['ACCURACY','PRECISION', 'RECALL','F1 SCORE','AUC']

# Function to create dataframe with metrics
def performanceMetricsDF(metricsObj, yTrain, yPredTrain, yTest, yPredTest, modelName, dataFrameToAssign=resultsDF_compare):
    measures_list = ['ACCURACY','PRECISION', 'RECALL','F1 SCORE','AUC']
    train_results = ["{0:.2}".format(metricsObj.accuracy_score(yTrain, yPredTrain)),
                     "{0:.2}".format(metricsObj.precision_score(yTrain, yPredTrain)),
                     "{0:.2}".format(metricsObj.recall_score(yTrain, yPredTrain)),
                     "{0:.2}".format(metricsObj.f1_score(yTrain, yPredTrain)),
                     "{0:.2}".format(metricsObj.roc_auc_score(yTrain, yPredTrain))
                     ]
    test_results = ["{0:.2}".format(metricsObj.accuracy_score(yTest, yPredTest)),
                    "{0:.2}".format(metricsObj.precision_score(yTest, yPredTest)),
                    "{0:.2}".format(metricsObj.recall_score(yTest, yPredTest)),
                    "{0:.2}".format(metricsObj.f1_score(yTest, yPredTest)),
                    "{0:.2}".format(metricsObj.roc_auc_score(yTest, yPredTest))
                    ]
    resultsDF = pd.DataFrame({"Measure": measures_list, "Train_{0}".format(modelName): train_results, "Test_{0}".format(modelName):test_results})

    dataFrameToAssign["Train_{0}".format(modelName)] = train_results
    dataFrameToAssign["Test_{0}".format(modelName)] = test_results
    return(resultsDF)

# %%
# predict y for X_train and X_test
y_pred_train = classModel.predict(X_train)
y_pred_test = classModel.predict(X_test)

# %%
# Function to plot confusion matrix - Adapted from https://github.com/DTrimarchi10/confusion_matrix/blob/master/cf_matrix.py
def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.
    Arguments
    ---------
    cf:            confusion matrix to be passed in
    group_names:   List of strings that represent the labels row by row to be shown in each square.
    categories:    List of strings containing the categories to be displayed on the x,y axis. Default is 'auto'
    count:         If True, show the raw number in the confusion matrix. Default is True.
    normalize:     If True, show the proportions for each category. Default is True.
    cbar:          If True, show the color bar. The cbar values are based off the values in the confusion matrix.
                   Default is True.
    xyticks:       If True, show x and y ticks. Default is True.
    xyplotlabels:  If True, show 'True Label' and 'Predicted Label' on the figure. Default is True.
    sum_stats:     If True, display summary statistics below the figure. Default is True.
    figsize:       Tuple representing the figure size. Default will be the matplotlib rcParams value.
    cmap:          Colormap of the values displayed from matplotlib.pyplot.cm. Default is 'Blues'
                   See http://matplotlib.org/examples/color/colormaps_reference.html

    title:         Title for the heatmap. Default is None.
    '''


    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))

        #if it is a binary confusion matrix, show some more stats
        if len(cf)==2:
            #Metrics for Binary Confusion Matrices
            precision = cf[1,1] / sum(cf[:,1])
            recall    = cf[1,1] / sum(cf[1,:])
            f1_score  = 2*precision*recall / (precision + recall)
            stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={:0.3f}".format(
                accuracy,precision,recall,f1_score)
        else:
            stats_text = "\n\nAccuracy={:0.3f}".format(accuracy)
    else:
        stats_text = ""


    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    ax = sns.heatmap(cf,annot=box_labels, fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)

    if xyplotlabels:
        plt.ylabel('True label')
        plt.xlabel('Predicted label' + stats_text)
    else:
        plt.xlabel(stats_text)

    if title:
        plt.title(title)

# %%
# Show the confusion matrix
cf = metrics.confusion_matrix(y_test,y_pred_test)
labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['0', '1']
make_confusion_matrix(cf,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %%
resultsDF = performanceMetricsDF(metrics, y_train, y_pred_train, y_test, y_pred_test,"LR")
resultsDF
# Out:
#      Measure Train_LR Test_LR
# 0   ACCURACY     0.86    0.75
# 1  PRECISION     0.81    0.83
# 2     RECALL     0.88    0.56
# 3   F1 SCORE     0.85    0.67
# 4        AUC     0.87    0.73

# %%
# Display target balance in the training dataset
print(collections.Counter(y_train))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="y", data=pd.DataFrame(data={'y':y_train}), ax=ax)
# Out:
# Counter({0.0: 34, 1.0: 25})
# <AxesSubplot:xlabel='y', ylabel='count'>

# %%
# Applyting SMOTE to generare new instances (oversampling)
sm = SMOTE(random_state=123, sampling_strategy=1.0)
X_train2, y_train2 = sm.fit_resample(X_train, y_train)

# Display target balance in the training dataset
print(collections.Counter(y_train2))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="y", data=pd.DataFrame(data={'y':y_train2}), ax=ax)
# Out:
# Counter({0.0: 34, 1.0: 34})
# <AxesSubplot:xlabel='y', ylabel='count'>

# %%
# Train de model
classModel.fit(X_train2, y_train2)

# Predict values
# predict y for X_train and X_test
y_pred_train = classModel.predict(X_train2)
y_pred_test = classModel.predict(X_test)

# Show performance results
resultsDF = performanceMetricsDF(metrics, y_train2, y_pred_train, y_test, y_pred_test,"LR")
resultsDF
# Out:
#      Measure Train_LR Test_LR
# 0   ACCURACY     0.87     0.8
# 1  PRECISION     0.79    0.78
# 2     RECALL      1.0    0.78
# 3   F1 SCORE     0.88    0.78
# 4        AUC     0.87     0.8

# %%
# ROC curve
visualizer = ROCAUC(classModel, classes=['0','1'])
visualizer.fit(X_train2, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'ROC Curves for LogisticRegression'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# ### Support Vector Machine

# %%
# Create the Target
y = ds_work['is_winner']

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(ds_work, y, test_size=0.25, stratify=y, random_state=123)

# %%
# Remove the Target from the training
X_train = X_train.drop(['is_winner'],axis=1)
X_test = X_test.drop(['is_winner'],axis=1)

# %%
# Dataframe for scaling
tempDF = ds_work.copy(deep=True)
tempDF.drop(columns='is_winner', inplace=True)

# Normalize training/test data
scaler = MinMaxScaler(feature_range=(0, 1))
tempDF_scaled = scaler.fit_transform(tempDF)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Display target balance in the training dataset
print(collections.Counter(y_train))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="is_winner", data=pd.DataFrame(data={'is_winner':y_train}), ax=ax)
# Out:
# Counter({0.0: 34, 1.0: 25})
# <AxesSubplot:xlabel='is_winner', ylabel='count'>

# %%
# Applyting SMOTE to generare new instances (oversampling)
sm = SMOTE(random_state=123, sampling_strategy=1.0)
X_train_scaled2, y_train2 = sm.fit_resample(X_train_scaled, y_train)

# Display target balance in the training dataset
print(collections.Counter(y_train2))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="is_winner", data=pd.DataFrame(data={'is_winner':y_train2}), ax=ax)
# Out:
# Counter({0.0: 34, 1.0: 34})
# <AxesSubplot:xlabel='is_winner', ylabel='count'>

# %%
# Create object and train the model
classModel = svm.SVC(gamma='scale', random_state=123, probability=True)
classModel.fit(X_train_scaled2, y_train2)
# Out:
# SVC(probability=True, random_state=123)

# %%
# predict y for X_train and X_test
y_pred_train = classModel.predict(X_train_scaled2)
y_pred_test = classModel.predict(X_test_scaled)

# %%
# Show the confusion matrix
cf = metrics.confusion_matrix(y_test,y_pred_test)
labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['0', '1']
make_confusion_matrix(cf,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %%
# Show performance results
resultsDF = performanceMetricsDF(metrics, y_train2, y_pred_train, y_test, y_pred_test,"SVM")
resultsDF
# Out:
#      Measure Train_SVM Test_SVM
# 0   ACCURACY      0.87      0.6
# 1  PRECISION       0.8     0.54
# 2     RECALL      0.97     0.78
# 3   F1 SCORE      0.88     0.64
# 4        AUC      0.87     0.62

# %%
# ROC curve
visualizer = ROCAUC(classModel, classes=['0','1'])
visualizer.fit(X_train_scaled2, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'ROC Curves for SVC'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# ### 6.3 K. Nearest Neighbor

# %%
# Create the Target
y = ds_work['is_winner']

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(ds_work, y, test_size=0.25, stratify=y, random_state=123)

# %%
# Remove the Target from the training
X_train = X_train.drop(['is_winner'],1)
X_test = X_test.drop(['is_winner'],1)
# Out:
# /var/folders/hw/0nn4k6y96p3grs2cw32myzzr0000gn/T/ipykernel_32502/776441785.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_train = X_train.drop(['is_winner'],1)
# /var/folders/hw/0nn4k6y96p3grs2cw32myzzr0000gn/T/ipykernel_32502/776441785.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_test = X_test.drop(['is_winner'],1)

# %%
# Dataframe for scaling
tempDF = ds_work.copy(deep=True)
tempDF.drop(columns='is_winner', inplace=True)

# Normalize training/test data
scaler = MinMaxScaler(feature_range=(0, 1))
tempDF_scaled = scaler.fit_transform(tempDF)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Display target balance in the training dataset
print(collections.Counter(y_train))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="is_winner", data=pd.DataFrame(data={'is_winner':y_train}), ax=ax)
# Out:
# Counter({0.0: 34, 1.0: 25})
# <AxesSubplot:xlabel='is_winner', ylabel='count'>

# %%
# Applyting SMOTE to generare new instances (oversampling)
sm = SMOTE(random_state=123, sampling_strategy=1.0)
X_train_scaled2, y_train2 = sm.fit_resample(X_train_scaled, y_train)

# Display target balance in the training dataset
print(collections.Counter(y_train2))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="is_winner", data=pd.DataFrame(data={'is_winner':y_train2}), ax=ax)
# Out:
# Counter({0.0: 34, 1.0: 34})
# <AxesSubplot:xlabel='is_winner', ylabel='count'>

# %%
#List Hyperparameters that we want to tune.
leaf_size = list(range(1,10))
n_neighbors = list(range(1,10))
p=[1,2]
weights = ['uniform','distance']
algorithm = ['auto','ball_tree','kd_tree','brute']
#Convert to dictionary
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p,weights=weights,algorithm=algorithm)

#Create new KNN object
knn = KNeighborsClassifier()
#Use GridSearch
clf = GridSearchCV(knn, hyperparameters, cv=10)

#Fit the Model
classModel= clf.fit(X_train_scaled2, y_train2)

#Print The value of best Hyperparameters
print('Best leaf_size:', classModel.best_estimator_.get_params()['leaf_size'])
print('Best p:', classModel.best_estimator_.get_params()['p'])
print('Best n_neighbors:', classModel.best_estimator_.get_params()['n_neighbors'])
print('Best weights:', classModel.best_estimator_.get_params()['weights'])
print('Best algorithm:', classModel.best_estimator_.get_params()['algorithm'])
# Out:
# Best leaf_size: 1
# Best p: 1
# Best n_neighbors: 3
# Best weights: distance
# Best algorithm: auto

# %%
# predict y for X_train and X_test
y_pred_train = classModel.predict(X_train_scaled2)
y_pred_test = classModel.predict(X_test_scaled)

# %%
# Show the confusion matrix
cf = metrics.confusion_matrix(y_test,y_pred_test)
labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['0', '1']
make_confusion_matrix(cf,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %%
# Show performance results
resultsDF = performanceMetricsDF(metrics, y_train2, y_pred_train, y_test, y_pred_test,"KNN")
resultsDF
# Out:
#      Measure Train_KNN Test_KNN
# 0   ACCURACY       1.0     0.75
# 1  PRECISION       1.0      0.7
# 2     RECALL       1.0     0.78
# 3   F1 SCORE       1.0     0.74
# 4        AUC       1.0     0.75

# %%
# ROC curve
visualizer = ROCAUC(classModel, classes=['0','1'])
visualizer.fit(X_train_scaled2, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'ROC Curves for GridSearchCV'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# ### 6.4 Neural Network

# %%
# Create the Target
y = ds_work['is_winner']

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(ds_work, y, test_size=0.25, stratify=y, random_state=123)

# %%
# Remove the Target from the training
X_train = X_train.drop(['is_winner'],1)
X_test = X_test.drop(['is_winner'],1)
# Out:
# /var/folders/hw/0nn4k6y96p3grs2cw32myzzr0000gn/T/ipykernel_32502/776441785.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_train = X_train.drop(['is_winner'],1)
# /var/folders/hw/0nn4k6y96p3grs2cw32myzzr0000gn/T/ipykernel_32502/776441785.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_test = X_test.drop(['is_winner'],1)

# %%
# Dataframe for scaling
tempDF = ds_work.copy(deep=True)
tempDF.drop(columns='is_winner', inplace=True)

# Normalize training/test data
scaler = MinMaxScaler(feature_range=(0, 1))
tempDF_scaled = scaler.fit_transform(tempDF)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Display target balance in the training dataset
print(collections.Counter(y_train))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="is_winner", data=pd.DataFrame(data={'is_winner':y_train}), ax=ax)
print(y_train.value_counts(normalize=True))
# Out:
# Counter({0.0: 34, 1.0: 25})
# 0.0    0.576271
# 1.0    0.423729
# Name: is_winner, dtype: float64

# %%
# Applyting SMOTE to generare new instances (oversampling)
sm = SMOTE(random_state=123, sampling_strategy=1.0)
X_train_scaled2, y_train2 = sm.fit_resample(X_train_scaled, y_train)

# Display target balance in the training dataset
print(collections.Counter(y_train2))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="is_winner", data=pd.DataFrame(data={'is_winner':y_train2}), ax=ax)
# Out:
# Counter({0.0: 34, 1.0: 34})
# <AxesSubplot:xlabel='is_winner', ylabel='count'>

# %%
grid_param = [{'hidden_layer_sizes':[20,40,60],
               'activation':['identity','logistic','tanh','relu'],
               'solver':['lbfgs','sgd','adam'],
               'alpha':[0.0001, 0.002, 0.05],
               'batch_size':['auto'],
               'learning_rate':['constant'],
               'learning_rate_init':[0.001, 0.002],
               'max_iter':[100,300,500,600,700,800,900,1000,2000],
               'random_state':[123]}]
reg = MLPClassifier()
grid = GridSearchCV(reg, grid_param, cv=5)
grid.fit(X_train, y_train)
print("Grid search best parameters: {}".format(grid.best_params_))
# Out:
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (700) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (800) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (900) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:559: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Grid search best parameters: {'activation': 'identity', 'alpha': 0.0001, 'batch_size': 'auto', 'hidden_layer_sizes': 60, 'learning_rate': 'constant', 'learning_rate_init': 0.002, 'max_iter': 100, 'random_state': 123, 'solver': 'adam'}
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Create object and train the model
classModel = MLPClassifier(**grid.best_params_)
classModel.fit(X_train_scaled2, y_train2)
# Out:
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(activation='identity', hidden_layer_sizes=60,
#               learning_rate_init=0.002, max_iter=100, random_state=123)

# %%
# predict y for X_train and X_test
y_pred_train = classModel.predict(X_train_scaled2)
y_pred_test = classModel.predict(X_test_scaled)

# %%
# Show the confusion matrix
cf = metrics.confusion_matrix(y_test,y_pred_test)
labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['0', '1']
make_confusion_matrix(cf,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %%
resultsDF = performanceMetricsDF(metrics, y_train2, y_pred_train, y_test, y_pred_test,"NN")
resultsDF
# Out:
#      Measure Train_NN Test_NN
# 0   ACCURACY      0.9    0.75
# 1  PRECISION     0.85    0.83
# 2     RECALL     0.97    0.56
# 3   F1 SCORE      0.9    0.67
# 4        AUC      0.9    0.73

# %%
# ROC curve
visualizer = ROCAUC(classModel, classes=['0','1'])
visualizer.fit(X_train_scaled2, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'ROC Curves for MLPClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# ### 6.5 Naive Bayes

# %%
# Create the Target
y = ds_work['is_winner']

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(ds_work, y, test_size=0.25, stratify=y, random_state=123)

# %%
# Remove the Target from the training
X_train = X_train.drop(['is_winner'],1)
X_test = X_test.drop(['is_winner'],1)
# Out:
# /var/folders/hw/0nn4k6y96p3grs2cw32myzzr0000gn/T/ipykernel_32502/776441785.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_train = X_train.drop(['is_winner'],1)
# /var/folders/hw/0nn4k6y96p3grs2cw32myzzr0000gn/T/ipykernel_32502/776441785.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_test = X_test.drop(['is_winner'],1)

# %%
# Display target balance in the training dataset
print(collections.Counter(y_train))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="is_winner", data=pd.DataFrame(data={'is_winner':y_train}), ax=ax)
print(y_train.value_counts(normalize=True))
# Out:
# Counter({0.0: 34, 1.0: 25})
# 0.0    0.576271
# 1.0    0.423729
# Name: is_winner, dtype: float64

# %%
# Applyting SMOTE to generare new instances (oversampling)
sm = SMOTE(random_state=123, sampling_strategy=1.0)
X_train2, y_train2 = sm.fit_resample(X_train, y_train)

# Display target balance in the training dataset
print(collections.Counter(y_train2))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="Exited", data=pd.DataFrame(data={'Exited':y_train2}), ax=ax)
# Out:
# Counter({0.0: 34, 1.0: 34})
# <AxesSubplot:xlabel='Exited', ylabel='count'>

# %%
# Create object and train the model
classModel = GaussianNB()
classModel.fit(X_train2, y_train2)
# Out:
# GaussianNB()

# %%
# predict y for X_train and X_test
y_pred_train = classModel.predict(X_train2)
y_pred_test = classModel.predict(X_test)

# %%
# Show the confusion matrix
cf = metrics.confusion_matrix(y_test,y_pred_test)
labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['0', '1']
make_confusion_matrix(cf,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %%
resultsDF = performanceMetricsDF(metrics, y_train2, y_pred_train, y_test, y_pred_test,"NB")
resultsDF
# Out:
#      Measure Train_NB Test_NB
# 0   ACCURACY     0.69     0.6
# 1  PRECISION     0.62    0.53
# 2     RECALL      1.0     1.0
# 3   F1 SCORE     0.76    0.69
# 4        AUC     0.69    0.64

# %%
# ROC curve
visualizer = ROCAUC(classModel, classes=['0','1'])
visualizer.fit(X_train2, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'ROC Curves for GaussianNB'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# ### 6.6 Decision Tree

# %%
# Create the Target
y = ds_work['is_winner']

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(ds_work, y, test_size=0.25, stratify=y, random_state=123)

# %%
# Remove the Target from the training
X_train = X_train.drop(['is_winner'],1)
X_test = X_test.drop(['is_winner'],1)
# Out:
# /var/folders/hw/0nn4k6y96p3grs2cw32myzzr0000gn/T/ipykernel_32502/776441785.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_train = X_train.drop(['is_winner'],1)
# /var/folders/hw/0nn4k6y96p3grs2cw32myzzr0000gn/T/ipykernel_32502/776441785.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_test = X_test.drop(['is_winner'],1)

# %%
# Display target balance in the training dataset
print(collections.Counter(y_train))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="is_winner", data=pd.DataFrame(data={'is_winner':y_train}), ax=ax)
print(y_train.value_counts(normalize=True))
# Out:
# Counter({0.0: 34, 1.0: 25})
# 0.0    0.576271
# 1.0    0.423729
# Name: is_winner, dtype: float64

# %%
# Applyting SMOTE to generare new instances (oversampling)
sm = SMOTE(random_state=123, sampling_strategy=1.0)
X_train2, y_train2 = sm.fit_resample(X_train, y_train)

# Display target balance in the training dataset
print(collections.Counter(y_train2))
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="is_winner", data=pd.DataFrame(data={'is_winner':y_train2}), ax=ax)
# Out:
# Counter({0.0: 34, 1.0: 34})
# <AxesSubplot:xlabel='is_winner', ylabel='count'>

# %%
# Create object and train the model
classModel = tree.DecisionTreeClassifier(max_depth=4, random_state=123)
classModel.fit(X_train2, y_train2)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=123)

# %%
grid_param = [{'criterion':['gini','entropy'],
               'max_depth':[2,3,4,5],
               'min_samples_split':[1, 2, 3,4],
               'min_samples_leaf':[1,2,3],
               'max_leaf_nodes':[1,2,3,4,5],
               'random_state':[123]}]
reg = tree.DecisionTreeClassifier()
grid = GridSearchCV(reg, grid_param, cv=5)
grid.fit(X_train, y_train)
print("Grid search best parameters: {}".format(grid.best_params_))
# Out:
# Grid search best parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 123}
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 960 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 969, in fit
#     super().fit(
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 265, in fit
#     check_scalar(
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 1480, in check_scalar
#     raise ValueError(
# ValueError: min_samples_split == 1, must be >= 2.
#
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 969, in fit
#     super().fit(
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py", line 350, in fit
#     check_scalar(
#   File "/Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py", line 1480, in check_scalar
#     raise ValueError(
# ValueError: max_leaf_nodes == 1, must be >= 2.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.61212121 0.61212121 0.61212121        nan 0.61212121
#  0.61212121 0.61212121        nan 0.61212121 0.61212121 0.61212121
#         nan 0.55909091 0.55909091 0.55909091        nan 0.55909091
#  0.55909091 0.55909091        nan 0.55909091 0.55909091 0.55909091
#         nan 0.54242424 0.54242424 0.54242424        nan 0.54242424
#  0.54242424 0.54242424        nan 0.52575758 0.52575758 0.52575758
#         nan 0.54242424 0.54242424 0.54242424        nan 0.54242424
#  0.54242424 0.54242424        nan 0.52575758 0.52575758 0.52575758
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.61212121 0.61212121 0.61212121        nan 0.61212121
#  0.61212121 0.61212121        nan 0.61212121 0.61212121 0.61212121
#         nan 0.55909091 0.55909091 0.55909091        nan 0.55909091
#  0.55909091 0.55909091        nan 0.55909091 0.55909091 0.55909091
#         nan 0.54242424 0.54242424 0.54242424        nan 0.54242424
#  0.54242424 0.54242424        nan 0.52575758 0.52575758 0.52575758
#         nan 0.56060606 0.56060606 0.56060606        nan 0.56060606
#  0.56060606 0.56060606        nan 0.54393939 0.54393939 0.54393939
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.61212121 0.61212121 0.61212121        nan 0.61212121
#  0.61212121 0.61212121        nan 0.61212121 0.61212121 0.61212121
#         nan 0.55909091 0.55909091 0.55909091        nan 0.55909091
#  0.55909091 0.55909091        nan 0.55909091 0.55909091 0.55909091
#         nan 0.54242424 0.54242424 0.54242424        nan 0.54242424
#  0.54242424 0.54242424        nan 0.52575758 0.52575758 0.52575758
#         nan 0.56060606 0.56060606 0.56060606        nan 0.56060606
#  0.56060606 0.56060606        nan 0.54393939 0.54393939 0.54393939
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.61212121 0.61212121 0.61212121        nan 0.61212121
#  0.61212121 0.61212121        nan 0.61212121 0.61212121 0.61212121
#         nan 0.55909091 0.55909091 0.55909091        nan 0.55909091
#  0.55909091 0.55909091        nan 0.55909091 0.55909091 0.55909091
#         nan 0.54242424 0.54242424 0.54242424        nan 0.54242424
#  0.54242424 0.54242424        nan 0.52575758 0.52575758 0.52575758
#         nan 0.56060606 0.56060606 0.56060606        nan 0.56060606
#  0.56060606 0.56060606        nan 0.54393939 0.54393939 0.54393939
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.57878788 0.57878788 0.57878788        nan 0.57878788
#  0.57878788 0.57878788        nan 0.57878788 0.57878788 0.57878788
#         nan 0.54242424 0.54242424 0.54242424        nan 0.54242424
#  0.54242424 0.54242424        nan 0.54242424 0.54242424 0.54242424
#         nan 0.52575758 0.52575758 0.52575758        nan 0.52575758
#  0.52575758 0.52575758        nan 0.54242424 0.54242424 0.54242424
#         nan 0.52575758 0.52575758 0.52575758        nan 0.52575758
#  0.52575758 0.52575758        nan 0.54242424 0.54242424 0.54242424
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.57878788 0.57878788 0.57878788        nan 0.57878788
#  0.57878788 0.57878788        nan 0.57878788 0.57878788 0.57878788
#         nan 0.54242424 0.54242424 0.54242424        nan 0.54242424
#  0.54242424 0.54242424        nan 0.54242424 0.54242424 0.54242424
#         nan 0.52575758 0.52575758 0.52575758        nan 0.52575758
#  0.52575758 0.52575758        nan 0.54242424 0.54242424 0.54242424
#         nan 0.52575758 0.52575758 0.52575758        nan 0.52575758
#  0.52575758 0.52575758        nan 0.54242424 0.54242424 0.54242424
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.57878788 0.57878788 0.57878788        nan 0.57878788
#  0.57878788 0.57878788        nan 0.57878788 0.57878788 0.57878788
#         nan 0.54242424 0.54242424 0.54242424        nan 0.54242424
#  0.54242424 0.54242424        nan 0.54242424 0.54242424 0.54242424
#         nan 0.52575758 0.52575758 0.52575758        nan 0.52575758
#  0.52575758 0.52575758        nan 0.54242424 0.54242424 0.54242424
#         nan 0.50909091 0.50909091 0.50909091        nan 0.52575758
#  0.52575758 0.52575758        nan 0.52575758 0.52575758 0.52575758
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.57878788 0.57878788 0.57878788        nan 0.57878788
#  0.57878788 0.57878788        nan 0.57878788 0.57878788 0.57878788
#         nan 0.54242424 0.54242424 0.54242424        nan 0.54242424
#  0.54242424 0.54242424        nan 0.54242424 0.54242424 0.54242424
#         nan 0.52575758 0.52575758 0.52575758        nan 0.52575758
#  0.52575758 0.52575758        nan 0.54242424 0.54242424 0.54242424
#         nan 0.50909091 0.50909091 0.50909091        nan 0.52575758
#  0.52575758 0.52575758        nan 0.52575758 0.52575758 0.52575758]
#   warnings.warn(

# %%
# Create object and train the model
classModel = tree.DecisionTreeClassifier(**grid.best_params_)
classModel.fit(X_train2, y_train2)
# Out:
# DecisionTreeClassifier(max_depth=2, max_leaf_nodes=2, random_state=123)

# %%
# predict y for X_train and X_test
y_pred_train = classModel.predict(X_train2)
y_pred_test = classModel.predict(X_test)

# %%
# Show the confusion matrix
cf = metrics.confusion_matrix(y_test,y_pred_test)
labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['0', '1']
make_confusion_matrix(cf,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %%
resultsDF = performanceMetricsDF(metrics, y_train2, y_pred_train, y_test, y_pred_test,"DT")
resultsDF
# Out:
#      Measure Train_DT Test_DT
# 0   ACCURACY     0.75    0.55
# 1  PRECISION     0.77     0.5
# 2     RECALL     0.71    0.56
# 3   F1 SCORE     0.74    0.53
# 4        AUC     0.75    0.55

# %%
# ROC curve
visualizer = ROCAUC(classModel, classes=['0','1'])
visualizer.fit(X_train2, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# /Users/franciscorfafonso/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'ROC Curves for DecisionTreeClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
# Loading the dataset where we stored the values of the models and checking it
eva = resultsDF_compare
eva.head(6)
# Out:
#      Measure Train_LR Test_LR Train_SVM Test_SVM Train_KNN Test_KNN Train_NN  \
# 0   ACCURACY     0.87     0.8      0.87      0.6       1.0     0.75      0.9
# 1  PRECISION     0.79    0.78       0.8     0.54       1.0      0.7     0.85
# 2     RECALL      1.0    0.78      0.97     0.78       1.0     0.78     0.97
# 3   F1 SCORE     0.88    0.78      0.88     0.64       1.0     0.74      0.9
# 4        AUC     0.87     0.8      0.87     0.62       1.0     0.75      0.9
#
#   Test_NN Train_NB Test_NB Train_DT Test_DT
# 0    0.75     0.69     0.6     0.75    0.55
# 1    0.83     0.62    0.53     0.77     0.5
# 2    0.56      1.0     1.0     0.71    0.56
# 3    0.67     0.76    0.69     0.74    0.53
# 4    0.73     0.69    0.64     0.75    0.55

# %%
eva.to_pickle('classification_model_evaluation.pkl')
